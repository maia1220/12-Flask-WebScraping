# %% [markdown]
# Step-by-step notebook (Extra Material for homework submission)
#
# Please don't use this for grading. Thanks!

# %%
from bs4 import BeautifulSoup as bs
import requests

# %% [markdown]
# NASA Mars News

# %%
url="https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest"

# %%
response= requests.get(url)

# %%
# soup=bs(response.text, 'html.parser')

soup=bs(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":283,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
# result=soup.find('div', class_='image_and_description_container')
result=soup.find('div', class_='image_and_description_container')

# for result in results:
#     print(result.text)

# %%
news_p=result.find('div', class_='rollover_description_inner').text.replace('\n','')
news_p
# Out:
# "Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet."

# %%
news_title=soup.find('div', class_='content_title').text.replace('\n', '')
news_title
# Out:
# "Alabama High School Student Names NASA's Mars Helicopter"

# %%
# Method 2

from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

from splinter import Browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)


url='https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)

html=browser.html
soup=bs(html, 'html.parser')
articles=soup.find("div", class_="slide")
print(articles)
# Out:
# <div class="slide slick-slide slick-cloned" index="-3" style="width: 332px;">
# <div class="image_and_description_container">
# <a href="/news/8634/109-million-names-now-aboard-nasas-perseverance-mars-rover/">
# <div class="rollover_description">
# <div class="rollover_description_inner">
# As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.
# </div>
# <div class="overlay_arrow">
# <img alt="More" src="/assets/overlay-arrow.png"/>
# </div>
# </div>
# <img alt="10.9 Million Names Now Aboard NASA's Perseverance Mars Rover" class="img-lazy" data-lazy="/system/news_items/list_view_images/8634_PIA23769-320x240.jpg" src="/assets/loading_320x240.png"/>
# </a>
# </div>
# <div class="content_title">
# <a href="/news/8634/109-million-names-now-aboard-nasas-perseverance-mars-rover/">
# 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
# </a>
# </div>
# </div>

# %%
item=articles.find('div', class_='rollover_description_inner').text.replace('\n', '')
item
# Out:
# "As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars."

# %%
titles=articles.find("div", class_="content_title").text.replace('\n', '')
titles
# Out:
# "10.9 Million Names Now Aboard NASA's Perseverance Mars Rover"

# %% [markdown]
# JPL Mars Space Images - Featured Image

# %%
from splinter import Browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)


url='https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

# %%
html=browser.html
soup=bs(html, 'html.parser')
items=soup.find('div', class_='carousel_container')

image=items.find('a')
image_link=image['data-fancybox-href']
website='https://www.jpl.nasa.gov'
featured_image_url = website + image_link
print(featured_image_url)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/mediumsize/PIA17761_ip.jpg

# %% [markdown]
# Mars Weather

# %%
url2='https://twitter.com/marswxreport?lang=en'
response2= requests.get(url2)
soup2=bs(response2.text, 'html.parser')
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html data-scribe-reduced-action-queue="true" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script nonce="tqeSPDQBUMi4NBXtKA8bjQ==">
#    !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#   </script>
#   <script id="bouncer_terminate_iframe" nonce="tqeSPDQBUMi4NBXtKA8bjQ==">
#    if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
#   <script id="swift_action_queue" nonce="tqeSPDQBUMi4NBXtKA8bjQ==">
# ...

# %%
result2=soup2.find_all('div', class_='js-tweet-text-container')

result2
# Out:
# [<div class="js-tweet-text-container">
#  <p class="TweetTextSize TweetTextSize--normal js-tweet-text tweet-text" data-aria-label-part="0" lang="en">InSight sol 533 (2020-05-27) low -92.8ºC (-135.1ºF) high -6.7ºC (19.9ºF)
#  winds from the SW at 6.4 m/s (14.2 mph) gusting to 21.3 m/s (47.5 mph)
#  pressure at 7.20 hPa<a class="twitter-timeline-link u-hidden" data-pre-embedded="true" dir="ltr" href="https://t.co/sKQ2HEz7A2">pic.twitter.com/sKQ2HEz7A2</a></p>
#  </div>,
#  <div class="js-tweet-text-container">
# ...

# %%
weather_list=[]

for result in result2:
    post= result.find('p', class_='js-tweet-text').text
    
    
    if 'InSight sol' in post:        
        print("-----")
#         print(post)
        post1=post.split('InSight')[1]
#         print(post1)
        weather=post1.split('pic.twitter')[0]
        print(weather)
        weather_list.append(weather)
    else:
        pass
# Out:
# -----
#  sol 533 (2020-05-27) low -92.8ºC (-135.1ºF) high -6.7ºC (19.9ºF)
# winds from the SW at 6.4 m/s (14.2 mph) gusting to 21.3 m/s (47.5 mph)
# pressure at 7.20 hPa
# -----
#  sol 532 (2020-05-26) low -93.1ºC (-135.7ºF) high -1.1ºC (30.0ºF)
# winds from the SW at 4.9 m/s (10.9 mph) gusting to 17.7 m/s (39.6 mph)
# pressure at 7.10 hPa
# -----
#  sol 531 (2020-05-24) low -93.5ºC (-136.2ºF) high -6.1ºC (21.0ºF)
# winds from the WNW at 5.6 m/s (12.5 mph) gusting to 21.1 m/s (47.3 mph)
# pressure at 7.10 hPa
# -----
#  sol 530 (2020-05-23) low -92.6ºC (-134.7ºF) high 0.4ºC (32.7ºF)
# winds from the SW at 4.7 m/s (10.6 mph) gusting to 17.4 m/s (38.9 mph)
# pressure at 7.10 hPa
# -----
#  sol 529 (2020-05-22) low -93.2ºC (-135.8ºF) high 0.6ºC (33.1ºF)
# winds from the WNW at 4.6 m/s (10.3 mph) gusting to 15.5 m/s (34.6 mph)
# pressure at 7.10 hPa
# -----
#  sol 528 (2020-05-22) low -93.5ºC (-136.3ºF) high -5.3ºC (22.4ºF)
# ...

# %%
mars_weather=weather_list[0].lstrip()
mars_weather=mars_weather.replace('sol', 'Sol')
print(mars_weather)
# Out:
# Sol 533 (2020-05-27) low -92.8ºC (-135.1ºF) high -6.7ºC (19.9ºF)
# winds from the SW at 6.4 m/s (14.2 mph) gusting to 21.3 m/s (47.5 mph)
# pressure at 7.20 hPa

# %% [markdown]
# Mars Facts

# %%
import pandas as pd

url3='https://space-facts.com/mars/'
tables=pd.read_html(url3)
for table in tables:
    print("-------")
    print(table)
# Out:
# -------
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers
# -------
#   Mars - Earth Comparison             Mars            Earth
# 0               Diameter:         6,779 km        12,742 km
# 1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 2                  Moons:                2                1
# 3      Distance from Sun:   227,943,824 km   149,598,262 km
# 4         Length of Year:   687 Earth days      365.24 days
# ...

# %%
type(tables)

mar_df=tables[0]
mar_df
# Out:
#                       0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mar_df.columns=['Fact', 'Metric']
mar_df
# Out:
#                    Fact                         Metric
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
mar_df.set_index('Fact')
# Out:
#                                              Metric
# Fact
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
html_table=mar_df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Fact</th>\n      <th>Metric</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.39 × 10^23 kg (0.11 Earths)</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.38 AU)</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Surface Temperature:</td>\n      <td>-87 to -5 °C</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>First Record:</td>\n      <td>2nd millennium BC</
# ...

# %%
new_html_table=html_table.replace('\n', '')

new_html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Fact</th>      <th>Metric</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Equatorial Diameter:</td>      <td>6,792 km</td>    </tr>    <tr>      <th>1</th>      <td>Polar Diameter:</td>      <td>6,752 km</td>    </tr>    <tr>      <th>2</th>      <td>Mass:</td>      <td>6.39 × 10^23 kg (0.11 Earths)</td>    </tr>    <tr>      <th>3</th>      <td>Moons:</td>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>4</th>      <td>Orbit Distance:</td>      <td>227,943,824 km (1.38 AU)</td>    </tr>    <tr>      <th>5</th>      <td>Orbit Period:</td>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>6</th>      <td>Surface Temperature:</td>      <td>-87 to -5 °C</td>    </tr>    <tr>      <th>7</th>      <td>First Record:</td>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>8</th>      <td>Recorded By:</td>      <td>Egyptian astronomers<
# ...

# %%
mar_df.to_html('mar_html_table')

# %%
# !open mar_html_table

# %% [markdown]
# Mars Hemispheres

# %%
url4='https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
browser.visit(url4)
html4=browser.html

soup4=bs(html4,'html.parser')
views=soup4.find_all('div', class_='description')

# %%
title_list=[]
url_list=[]

for view in views:
    title=view.find('h3').text
    title=title.replace('Enhanced', '')
    print("----------")
    title_list.append(title)
    print(title)
    try:
        executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
        browser = Browser('chrome', **executable_path, headless=False)
        browser.visit(url4)
        browser.links.find_by_partial_text(title)
        html5=browser.html
        soup5=bs(html5, 'html.parser')
        images=soup5.find_all('div', class_='wide-image-wrapper')
        for image in images:
            image_url= image.find('li').find('a')['href']
            url_list.append(image_url)
            print(image_url)        
    except:
        print('Error')
# Out:
# ----------
# Cerberus Hemisphere
# //anaconda3/lib/python3.7/site-packages/splinter/driver/webdriver/__init__.py:528: FutureWarning: browser.find_link_by_partial_text is deprecated. Use browser.links.find_by_partial_text instead.
#   FutureWarning,
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg
# ----------
# Schiaparelli Hemisphere
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg
# ----------
# Syrtis Major Hemisphere
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg
# ----------
# Valles Marineris Hemisphere
# https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg

# %%
hemisphere_image_urls = [
    {'title': title_list[0], 'image_url': url_list[0]},
    {'title': title_list[1], 'image_url': url_list[1]},
    {'title': title_list[2], 'image_url': url_list[2]},
    {'title': title_list[3], 'image_url': url_list[3]},
]

print(hemisphere_image_urls)
# Out:
# [{'title': 'Cerberus Hemisphere ', 'image_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}, {'title': 'Schiaparelli Hemisphere ', 'image_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg'}, {'title': 'Syrtis Major Hemisphere ', 'image_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg'}, {'title': 'Valles Marineris Hemisphere ', 'image_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}]

# %%
# !pip install Flask-PyMongo
